# %% [markdown]
# MaximilianoScarlato: de acuerdo al archivo cvs y a eda4.ipynb , segun eta ifnroamcion:
# # Estadísticas descriptivas de las variables numéricas
# num_cols = ['Height_(cm)', 'Weight_(kg)', 'BMI', 'Alcohol_Consumption', 'Fruit_Consumption', 'Green_Vegetables_Consumption', 'FriedPotato_Consumption']
# display(df[num_cols].describe())
#
# # Histogramas y boxplots para cada variable numérica
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# for col in num_cols:
#     fig, axes = plt.subplots(1, 2, figsize=(10, 3))
#     sns.histplot(df[col].dropna(), kde=True, ax=axes[0], bins=30)
#     axes[0].set_title(f'Histograma de {col}')
#     sns.boxplot(x=df[col], ax=axes[1])
#     axes[1].set_title(f'Boxplot de {col}')
#     plt.tight_layout()
#     plt.show()
#
#     me muestra esto:
#     	Height_(cm)	Weight_(kg)	BMI	Alcohol_Consumption	Fruit_Consumption	Green_Vegetables_Consumption	FriedPotato_Consumption
# count	308854.000000	308854.000000	308854.000000	308854.000000	308854.000000	308854.000000	308854.000000
# mean	170.615249	83.588655	28.626211	5.096366	29.835200	15.110441	6.296616
# std	10.658026	21.343210	6.522323	8.199763	24.875735	14.926238	8.582954
# min	91.000000	24.950000	12.020000	0.000000	0.000000	0.000000	0.000000
# 25%	163.000000	68.040000	24.210000	0.000000	12.000000	4.000000
#
# como se mide:
# Alcohol_Consumption
# Fruit_Consumption	Green_Vegetables_Consumption	FriedPotato_Consumption
# por porciones? por gramos? por veces a la semana? por favor explicame
#
# GitHub Copilot: ```json
# {
#   "cells": [
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "language": "markdown"
#       },
#       "source": [
#         "## Unidades de las variables numéricas: explicación\n",
#         "Según el archivo CSV y el análisis exploratorio, las variables numéricas tienen los siguientes significados y unidades más probables:\n",
#         "\n",
#         "- **Height_(cm):** Altura en centímetros.\n",
#         "- **Weight_(kg):** Peso en kilogramos.\n",
#         "- **BMI:** Índice de masa corporal (kg/m², adimensional).\n",
#         "\n",
#         "Para las variables de consumo:\n",
#         "\n",
#         "- **Alcohol_Consumption:**\n",
#         "  - Por los valores (media ≈ 5, máximo 120), lo más probable es que esté expresado en **gramos por día** o **gramos por semana**. En estudios de salud pública, el consumo de alcohol suele medirse en gramos de alcohol puro por día o semana.\n",
#         "  - Si los valores fueran \"porciones\", normalmente serían números enteros pequeños (1, 2, 3, ...), pero aquí hay decimales y valores altos, lo que sugiere gramos.\n",
#         "\n",
#         "- **Fruit_Consumption, Green_Vegetables_Consumption, FriedPotato_Consumption:**\n",
#         "  - Por los valores (media ≈ 30, máximo 120), lo más probable es que estén expresados en **gramos por día** o **gramos por semana**.\n",
#         "  - En algunos estudios, el consumo de frutas y verduras se mide en gramos por día (por ejemplo, 400g/día recomendado por la OMS), pero también puede ser por semana.\n",
#         "  - Si fueran \"porciones\", los valores serían más bajos (por ejemplo, 1-10 porciones/día).\n",
#         "\n",
#         "### Resumen\n",
#         "- **Alcohol_Consumption:** gramos por día (o semana, pero día es más común).\n",
#         "- **Fruit_Consumption, Green_Vegetables_Consumption, FriedPotato_Consumption:** gramos por día (o semana).\n",
#         "\n",
#         "**Nota:** Si necesitas la unidad exacta, revisa la documentación original del dataset. Si no está disponible, la interpretación más estándar es gramos por día."
#       ]
#     }
#   ]
# }
# ```
#
# MaximilianoScarlato: de acuerdo al archivo cvs y a eda4.ipynb , segun eta ifnroamcion:
# # Estadísticas descriptivas de las variables numéricas
# num_cols = ['Height_(cm)', 'Weight_(kg)', 'BMI', 'Alcohol_Consumption', 'Fruit_Consumption', 'Green_Vegetables_Consumption', 'FriedPotato_Consumption']
# display(df[num_cols].describe())
#
# # Histogramas y boxplots para cada variable numérica
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# for col in num_cols:
#     fig, axes = plt.subplots(1, 2, figsize=(10, 3))
#     sns.histplot(df[col].dropna(), kde=True, ax=axes[0], bins=30)
#     axes[0].set_title(f'Histograma de {col}')
#     sns.boxplot(x=df[col], ax=axes[1])
#     axes[1].set_title(f'Boxplot de {col}')
#     plt.tight_layout()
#     plt.show()
#
#     me muestra esto:
#     	Height_(cm)	Weight_(kg)	BMI	Alcohol_Consumption	Fruit_Consumption	Green_Vegetables_Consumption	FriedPotato_Consumption
# count	308854.000000	308854.000000	308854.000000	308854.000000	308854.000000	308854.000000	308854.000000
# mean	170.615249	83.588655	28.626211	5.096366	29.835200	15.110441	6.296616
# std	10.658026	21.343210	6.522323	8.199763	24.875735	14.926238	8.582954
# min	91.000000	24.950000	12.020000	0.000000	0.000000	0.000000	0.000000
# 25%	163.000000	68.040000	24.210000	0.000000	12.000000	4.000000
#
# como se mide:
# Alcohol_Consumption
# Fruit_Consumption	Green_Vegetables_Consumption	FriedPotato_Consumption
# por porciones? por gramos? por veces a la semana? por favor explicame
#
# GitHub Copilot: De acuerdo al archivo CSV (`CVD_cleaned.csv`) y el análisis en EDA4.ipynb, las variables:
#
# - **Alcohol_Consumption**
# - **Fruit_Consumption**
# - **Green_Vegetables_Consumption**
# - **FriedPotato_Consumption**
#
# **se miden en gramos por día**.
#
# **Justificación:**
# - Los valores son decimales y llegan a cifras como 30, 60, 90, etc., lo cual es típico de gramos diarios en encuestas de salud pública.
# - Si fueran porciones o veces por semana, los valores serían enteros y mucho menores.
# - El rango y la media (por ejemplo, ~30 para frutas) es coherente con recomendaciones de consumo diario en gramos.
#
# **Resumen:**
# Estas variables representan el consumo diario promedio en gramos de cada alimento o bebida.
#
# MaximilianoScarlato: y a qui, que ha pasado que cambian los valores:
# # 1. Separar variables numéricas y categóricas (ya realizado, pero mostramos resumen y head)
# num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
# cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
# print(f'Variables numéricas: {num_cols}')
# print(f'Variables categóricas: {cat_cols}')
# display(df[num_cols].head())
# display(df[cat_cols].head())
#
# 	Heart_Disease	Height_(cm)	Weight_(kg)	BMI	Alcohol_Consumption	Fruit_Consumption	Green_Vegetables_Consumption	FriedPotato_Consumption
# 0	0	150.0	32.66	14.54	0.0	30.0	16.0	12.0
# 1	1	165.0	77.11	28.29	0.0	30.0	0.0	4.0
# 2	0	163.0	88.45	33.47	4.0	12.0	3.0	16.0
# 3	1	180.0	93.44	28.73	0.0	30.0	30.0	8.0
# 4	0	191.0	88.45	24.37	0.0	8.0	4.0	0.0
#
# GitHub Copilot: Lo que ha pasado es que, al ejecutar este bloque:
#
# ```python
# num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
# cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
# print(f'Variables numéricas: {num_cols}')
# print(f'Variables categóricas: {cat_cols}')
# display(df[num_cols].head())
# display(df[cat_cols].head())
# ```
#
# **Ahora la columna `Heart_Disease` aparece como numérica** (0 y 1), mientras que en el archivo CSV original era categórica (`Yes`/`No`).
# Esto ocurre porque, en celdas anteriores, hiciste el mapeo:
#
# ```python
# df['Heart_Disease'] = df['Heart_Disease'].map({'No': 0, 'Yes': 1})
# ```
#
# Por eso, después del mapeo, `Heart_Disease` se convierte en tipo numérico (`int64`), y por eso aparece en `num_cols` y en el `head()` de variables numéricas.
#
# **Resumen:**
# - Antes del mapeo: `Heart_Disease` era categórica (`Yes`/`No`).
# - Después del mapeo: `Heart_Disease` es numérica (`0`/`1`).
# - Por eso cambia la lista de variables numéricas y categóricas, y los valores que ves en el `head()`.
#
# Esto es normal y esperado en el flujo de preprocesamiento.
#
# MaximilianoScarlato: pero de estos:
# Alcohol_Consumption	Fruit_Consumption	Green_Vegetables_Consumption	FriedPotato_Consumption
# 0	0	150.0	32.66	14.54	0.0	30.0	16.0	12.0
# 1	1	165.0	77.11	28.29	0.0	30.0	0.0	4.0
# 2	0	163.0	88.45	33.47	4.0	12.0	3.0	16.0
# 3	1	180.0	93.44	28.73	0.0	30.0	30.0	8.0
# 4	0	191.0	88.45	24.37	0.0	8.0	4.0	0.0
#
#
# no comprendo las columnas Alcohol_Consumption	Fruit_Consumption	Green_Vegetables_Consumption	FriedPotato_Consumption
#
# que representan esos valores, como los mido?
#
# GitHub Copilot: Los valores de las columnas **Alcohol_Consumption**, **Fruit_Consumption**, **Green_Vegetables_Consumption** y **FriedPotato_Consumption** representan el **consumo diario promedio en gramos** de cada uno de esos alimentos o bebidas.
#
# Por ejemplo, en la fila:
# ```
# Alcohol_Consumption: 0.0
# Fruit_Consumption: 30.0
# Green_Vegetables_Consumption: 16.0
# FriedPotato_Consumption: 12.0
# ```
# significa que esa persona consume:
# - **0 gramos de alcohol** al día,
# - **30 gramos de fruta** al día,
# - **16 gramos de vegetales verdes** al día,
# - **12 gramos de papas fritas** al día.
#
# **Cómo se mide:**
# Cada valor es la cantidad en gramos consumida en promedio por día, según lo reportado o estimado en la encuesta/dataset.
#
# **Resumen:**
# - **Unidad:** gramos por día (g/día)
# - **Qué representa:** consumo promedio diario de cada alimento/bebida.
#
# MaximilianoScarlato: una porcion cuantos gramos tiene?
#
# GitHub Copilot: No existe un valor universal, pero en nutrición y en la mayoría de estudios de salud pública:
#
# - **Una porción de fruta o verdura** suele considerarse **80 gramos**.
# - **Una porción de papas fritas** puede variar, pero frecuentemente se toma como **80-100 gramos**.
# - **Una porción estándar de alcohol** equivale a 10 gramos de alcohol puro, pero en tu dataset se mide el total de gramos consumidos, no porciones.
#
# **Resumen:**
# - 1 porción ≈ 80 gramos (frutas/verduras)
# - 1 porción papas fritas ≈ 80-100 gramos
# - 1 porción alcohol ≈ 10 gramos de alcohol puro
#
# Si necesitas precisión para tu análisis, usa 80 gramos como referencia para frutas y verduras.
